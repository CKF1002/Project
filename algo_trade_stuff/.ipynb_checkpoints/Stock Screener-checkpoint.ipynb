# %% [markdown]
# 45
#
# market cap > 2bil
# IPO 5yrs
# PE > 0
# 50 ma
# 200 ma
# ROI > 10%
# sales growth 5yr > 30%
#
# price > 50ma > 200ma
# 200 ma uptrend
#
# Revenue
# Stable
# CAGR 3yr > 10%
# 1yr > 3yr > 5yr
#
# EPS
# EPSg% 3yr +ve
# or Eps 1yr turn +ve
#
# roci 3yr > 10%
# ev/ebitda
#
#
# Market leaders
# Moat
# Policy
# revenue stable
#
#
#
#
#
# 靚股
#
# market cap > 2 bil
# EPSg 15%+
# ROE 15%+
# IPO 5yrs
# PE > 0
#
# ROE/ EPS
# 5-10yr
# 同行比較
# 12-15%+ (10yr 1 exception)
# stability
#
# CFO +
# CFI -
#
# FCFg 10yr 5yrs +ve
# CFO-CFI
#
#
#
# bonus
# 3大指數
# ev/ebit <10 (no -ve)
# roic >10%

# %% [markdown]
# # FINVIZ

# %%
#!pip install requests

# %%
import requests

screen = requests.get('http://finviz.com/screener.ashx').text

print(screen)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
#     <title>Just a moment...</title>
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#     <meta name="robots" content="noindex,nofollow">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet">
#     <meta http-equiv="refresh" content="35">
#
# </head>
# <body class="no-js">
#     <div class="main-wrapper" role="main">
#     <div class="main-content">
#         <h1 class="zone-name-title h1">
#             <img class="heading-favicon" src="/favicon.ico"
#                  onerror="this.onerror=null;this.parentNode.removeChild(this)">
#             finviz.com
#         </h1>
#         <h2 class="h2" id="challenge-running">
#             Checking if the site connection is secure
#         </h2>
#         <noscript>
#             <div id="challenge-error-title">
# ...

# %%
import analysis_engine.finviz.fetch_api as fv

url = (
    'https://finviz.com/screener.ashx?'
    'v=111&'
    'f=cap_midunder,exch_nyse,fa_div_o5,idx_sp500'
    '&ft=4')
res = fv.fetch_tickers_from_screener(url=url)
print(res)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-7a385a697616> in <module>
# ----> 1 import analysis_engine.finviz.fetch_api as fv
#       2
#       3 url = (
#       4     'https://finviz.com/screener.ashx?'
#       5     'v=111&'
#
# ModuleNotFoundError: No module named 'analysis_engine'
