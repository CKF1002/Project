# %%
import matplotlib.pyplot as plt
from skimage.data import shepp_logan_phantom

# %%
# %%timeit #-r 1 -n 1
fig, ax = plt.subplots()
ax.matshow(shepp_logan_phantom())
plt.show(fig)
# Out:
# 174 ms ± 6.99 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
